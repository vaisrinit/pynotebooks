# %%
import pandas as pd
import pymongo
import regex as re
from nltk.tokenize import WordPunctTokenizer
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import plotly

# %%
myclient = pymongo.MongoClient('mongodb://localhost:27017/')
mydb = myclient["tweets"]
mycol = mydb["ministries_tweets"]
mydoc = mycol.find().sort("created_at", -1)

# %%
df =  pd.DataFrame(list(mydoc))

# %%
df.head()
# Out:
#                         _id          created_at                   id  \
# 0  63161c9b6f461f12e93f068c 2022-09-05 15:57:28  1566817801838350336
# 1  63161c9b6f461f12e93f068d 2022-09-05 15:57:06  1566817710780010496
# 2  63161c9b6f461f12e93f068e 2022-09-05 15:49:19  1566815751688065027
# 3  63161c9b6f461f12e93f068f 2022-09-05 15:42:34  1566814053057830912
# 4  63161c9b6f461f12e93f0690 2022-09-05 15:41:08  1566813689038401541
#
#                 id_str                                               text  \
# 0  1566817801838350336  RT @JoshiPralhad: Become part of 2 days Nation...
# 1  1566817710780010496  RT @PIB_Coal: https://t.co/VdAj2lLILx\nOverall...
# 2  1566815751688065027  RT @Rajeev_GoI: Expert Committee on DLI Scheme...
# 3  1566814053057830912  Let’s check your knowledge about steel.\n#DidY...
# 4  1566813689038401541  RT @dpradhanbjp: #PMShriSchools~14,500 exempla...
#
#    truncated                                           entities  \
# 0      False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1      False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2      False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3      False  {'hashtags': [{'text': 'DidYouKnow', 'indices'...
# 4      False  {'hashtags': [{'text': 'PMShriSchools', 'indic...
#
#                                               source in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/android" ...                  None
# 1  <a href="http://twitter.com/download/android" ...                  None
# 2  <a href="http://twitter.com/download/iphone" r...                  None
# 3  <a href="http://twitter.com/download/android" ...                  None
# 4  <a href="http://twitter.com/download/iphone" r...                  None
#
#   in_reply_to_status_id_str  ... retweet_count favorite_count favorited  \
# 0                      None  ...           108              0     False
# 1                      None  ...            11              0     False
# 2                      None  ...             4              0     False
# 3                      None  ...             0              3     False
# 4                      None  ...            25              0     False
#
#   retweeted lang possibly_sensitive  \
# 0     False   en                NaN
# 1     False   en              False
# 2     False   en                NaN
# 3     False   en              False
# 4     False   en                NaN
#
#                                    extended_entities quoted_status_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3  {'media': [{'id': 1566814041435406337, 'id_str...              NaN
# 4                                                NaN              NaN
#
#   quoted_status_id_str  quoted_status
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['_id', 'created_at', 'id', 'id_str', 'text', 'truncated', 'entities',
#        'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count',
#        'favorite_count', 'favorited', 'retweeted', 'lang',
#        'possibly_sensitive', 'extended_entities', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status'],
#       dtype='object')

# %%
tweets=df['text']

# %%
pd.options.display.max_colwidth = 200

# %%
tweets
# Out:
# 0        RT @JoshiPralhad: Become part of 2 days National Mines Minister's Conference on 9th &amp; 10th hosted by @MinesMinIndia.\n\nMinisters, Principle…
# 1            RT @PIB_Coal: https://t.co/VdAj2lLILx\nOverall coal production  goes up to 58.33 million ton in August ;  25 mines' production goes beyond 1…
# 2             RT @Rajeev_GoI: Expert Committee on DLI Scheme met at @GoI_MeitY tdy to brainstorm strategy n roadmap for creating 100 new Indian startups/…
# 3                                            Let’s check your knowledge about steel.\n#DidYouKnow \n#ispatigyan #AatmaNirbharSteel https://t.co/6HUsTqNJLf
# 4             RT @dpradhanbjp: #PMShriSchools~14,500 exemplar schools across the country to showcase the implementation of NEP 2020 and facilitate creati…
#                                                                                ...
# 16168        The Dekho Apna Desh webinars have been narrating interesting travel stories from various corners of India.\nBringing… https://t.co/KmA4RVlQJs
# 16169         महाभारत में अपनी आवाज़ (मैं समय हूं) के लिए प्रसिद्ध एवं राष्ट्रीय फिल्मफेयर पुरस्कार से सम्मानित हरीश भिमानी जी ने… https://t.co/eNYZ1fsSv8
# 16170          RT @AAI_Official: Located at a distance of 55 km from #Kolhapur, Gaganbawada offers the most scenic views of the mighty mountain ranges of…
# 16171     India, a vibrant democracy 🇮🇳\n\n2 out of 3 eligible Indians cast their vote 🗳️\n\n💠India, the largest democracy in the… https://t.co/nJTTirGZCM
# 16172     RT @devusinh: The excitement and josh are high at @IndiaPostOffice for #HarGharTiranga \n\nHow is your preparations?\n\nDon't forget to visit y…
# Name: text, Length: 16173, dtype: object

# %%
a = tweets.loc[1272]

# %%
print(a)
# Out:
# The 2nd session of the capacity building exercise on ‘Sexual Harassment of Women at Workplace Act, 2013’ was conduc… https://t.co/qGleIAR9JK

# %%
regex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
a = re.sub(regex_pattern,'',a) #replaces pattern with ''
print(a)
# Out:
# The 2nd session of the capacity building exercise on ‘Sexual Harassment of Women at Workplace Act, 2013’ was conduc… https://t.co/qGleIAR9JK

# %%
pattern = re.compile(r'(https?://)?(www\.)?(\w+\.)?(\w+)(\.\w+)(/.+)?')
a = re.sub(pattern,'',a)
print(a)
# Out:
# The 2nd session of the capacity building exercise on ‘Sexual Harassment of Women at Workplace Act, 2013’ was conduc…

# %%
re_list = ['@[A-Za-z0–9_]+', '#']
combined_re = re.compile( '|'.join( re_list) )
a = re.sub(combined_re,'',a)
print(a)
# Out:
# The 2nd session of the capacity building exercise on ‘Sexual Harassment of Women at Workplace Act, 2013’ was conduc…

# %%
def cleaning_tweets(t):
    token = WordPunctTokenizer()
    regex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    pattern = re.compile(r'(https?://)?(www\.)?(\w+\.)?(\w+)(\.\w+)(/.+)?')
    re_list = ['@[A-Za-z0–9_]+', '#']
    combined_re = re.compile( '|'.join( re_list) )
    del_amp = BeautifulSoup(t, 'lxml')
    del_amp_text = del_amp.get_text()
    del_link=re.sub(combined_re, '', del_amp_text)
    del_mentions = re.sub(pattern, '', del_link)
    del_emoticons = re.sub(regex_pattern, '', del_link)
    lower_case = del_emoticons.lower()
    words = token.tokenize(lower_case)
    result_words = [x for x in words if len(x) > 2]
    return (" ".join(result_words)).strip()

# %%
print("Cleaning the tweets...\n")
cleaned_tweets = []
for idx,tweet in enumerate(tweets): #3000 columns in our dataframe
    if( (idx+1)%100 == 0 ):
        print("Tweets {} of {} have ben processed".format(idx+1,len(tweets)))                                                                  
    cleaned_tweets.append(cleaning_tweets((tweet)))
# Out:
# Cleaning the tweets...
#
# Tweets 100 of 16173 have ben processed
# Tweets 200 of 16173 have ben processed
# Tweets 300 of 16173 have ben processed
# Tweets 400 of 16173 have ben processed
# C:\Users\Lenovo\anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# Tweets 500 of 16173 have ben processed
# Tweets 600 of 16173 have ben processed
# Tweets 700 of 16173 have ben processed
# Tweets 800 of 16173 have ben processed
# Tweets 900 of 16173 have ben processed
# Tweets 1000 of 16173 have ben processed
# Tweets 1100 of 16173 have ben processed
# Tweets 1200 of 16173 have ben processed
# Tweets 1300 of 16173 have ben processed
# Tweets 1400 of 16173 have ben processed
# C:\Users\Lenovo\anaconda3\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# Tweets 1500 of 16173 have ben processed
# Tweets 1600 of 16173 have ben processed
# Tweets 1700 of 16173 have ben processed
# Tweets 1800 of 16173 have ben processed
# Tweets 1900 of 16173 have ben processed
# Tweets 2000 of 16173 have ben processed
# Tweets 2100 of 16173 have ben processed
# Tweets 2200 of 16173 have ben processed
# Tweets 2300 of 16173 have ben processed
# Tweets 2400 of 16173 have ben processed
# Tweets 2500 of 16173 have ben processed
# Tweets 2600 of 16173 have ben processed
# Tweets 2700 of 16173 have ben processed
# Tweets 2800 of 16173 have ben processed
# Tweets 2900 of 16173 have ben processed
# Tweets 3000 of 16173 have ben processed
# Tweets 3100 of 16173 have ben processed
# Tweets 3200 of 16173 have ben processed
# Tweets 3300 of 16173 have ben processed
# Tweets 3400 of 16173 have ben processed
# Tweets 3500 of 16173 have ben processed
# Tweets 3600 of 16173 have ben processed
# Tweets 3700 of 16173 have ben processed
# Tweets 3800 of 16173 have ben processed
# Tweets 3900 of 16173 have ben processed
# Tweets 4000 of 16173 have ben processed
# Tweets 4100 of 16173 have ben processed
# Tweets 4200 of 16173 have ben processed
# Tweets 4300 of 16173 have ben processed
# Tweets 4400 of 16173 have ben processed
# Tweets 4500 of 16173 have ben processed
# Tweets 4600 of 16173 have ben processed
# Tweets 4700 of 16173 have ben processed
# Tweets 4800 of 16173 have ben processed
# Tweets 4900 of 16173 have ben processed
# Tweets 5000 of 16173 have ben processed
# Tweets 5100 of 16173 have ben processed
# Tweets 5200 of 16173 have ben processed
# Tweets 5300 of 16173 have ben processed
# Tweets 5400 of 16173 have ben processed
# Tweets 5500 of 16173 have ben processed
# Tweets 5600 of 16173 have ben processed
# Tweets 5700 of 16173 have ben processed
# Tweets 5800 of 16173 have ben processed
# Tweets 5900 of 16173 have ben processed
# Tweets 6000 of 16173 have ben processed
# Tweets 6100 of 16173 have ben processed
# Tweets 6200 of 16173 have ben processed
# Tweets 6300 of 16173 have ben processed
# Tweets 6400 of 16173 have ben processed
# Tweets 6500 of 16173 have ben processed
# Tweets 6600 of 16173 have ben processed
# Tweets 6700 of 16173 have ben processed
# Tweets 6800 of 16173 have ben processed
# Tweets 6900 of 16173 have ben processed
# Tweets 7000 of 16173 have ben processed
# Tweets 7100 of 16173 have ben processed
# Tweets 7200 of 16173 have ben processed
# Tweets 7300 of 16173 have ben processed
# Tweets 7400 of 16173 have ben processed
# Tweets 7500 of 16173 have ben processed
# Tweets 7600 of 16173 have ben processed
# Tweets 7700 of 16173 have ben processed
# Tweets 7800 of 16173 have ben processed
# Tweets 7900 of 16173 have ben processed
# Tweets 8000 of 16173 have ben processed
# Tweets 8100 of 16173 have ben processed
# Tweets 8200 of 16173 have ben processed
# Tweets 8300 of 16173 have ben processed
# Tweets 8400 of 16173 have ben processed
# Tweets 8500 of 16173 have ben processed
# Tweets 8600 of 16173 have ben processed
# Tweets 8700 of 16173 have ben processed
# Tweets 8800 of 16173 have ben processed
# Tweets 8900 of 16173 have ben processed
# Tweets 9000 of 16173 have ben processed
# Tweets 9100 of 16173 have ben processed
# Tweets 9200 of 16173 have ben processed
# Tweets 9300 of 16173 have ben processed
# Tweets 9400 of 16173 have ben processed
# Tweets 9500 of 16173 have ben processed
# Tweets 9600 of 16173 have ben processed
# Tweets 9700 of 16173 have ben processed
# Tweets 9800 of 16173 have ben processed
# Tweets 9900 of 16173 have ben processed
# Tweets 10000 of 16173 have ben processed
# Tweets 10100 of 16173 have ben processed
# Tweets 10200 of 16173 have ben processed
# Tweets 10300 of 16173 have ben processed
# Tweets 10400 of 16173 have ben processed
# Tweets 10500 of 16173 have ben processed
# Tweets 10600 of 16173 have ben processed
# Tweets 10700 of 16173 have ben processed
# Tweets 10800 of 16173 have ben processed
# Tweets 10900 of 16173 have ben processed
# Tweets 11000 of 16173 have ben processed
# Tweets 11100 of 16173 have ben processed
# Tweets 11200 of 16173 have ben processed
# Tweets 11300 of 16173 have ben processed
# Tweets 11400 of 16173 have ben processed
# Tweets 11500 of 16173 have ben processed
# Tweets 11600 of 16173 have ben processed
# Tweets 11700 of 16173 have ben processed
# Tweets 11800 of 16173 have ben processed
# Tweets 11900 of 16173 have ben processed
# Tweets 12000 of 16173 have ben processed
# Tweets 12100 of 16173 have ben processed
# Tweets 12200 of 16173 have ben processed
# Tweets 12300 of 16173 have ben processed
# Tweets 12400 of 16173 have ben processed
# Tweets 12500 of 16173 have ben processed
# Tweets 12600 of 16173 have ben processed
# Tweets 12700 of 16173 have ben processed
# Tweets 12800 of 16173 have ben processed
# Tweets 12900 of 16173 have ben processed
# Tweets 13000 of 16173 have ben processed
# Tweets 13100 of 16173 have ben processed
# Tweets 13200 of 16173 have ben processed
# Tweets 13300 of 16173 have ben processed
# Tweets 13400 of 16173 have ben processed
# Tweets 13500 of 16173 have ben processed
# Tweets 13600 of 16173 have ben processed
# Tweets 13700 of 16173 have ben processed
# Tweets 13800 of 16173 have ben processed
# Tweets 13900 of 16173 have ben processed
# Tweets 14000 of 16173 have ben processed
# Tweets 14100 of 16173 have ben processed
# Tweets 14200 of 16173 have ben processed
# Tweets 14300 of 16173 have ben processed
# Tweets 14400 of 16173 have ben processed
# Tweets 14500 of 16173 have ben processed
# Tweets 14600 of 16173 have ben processed
# Tweets 14700 of 16173 have ben processed
# Tweets 14800 of 16173 have ben processed
# Tweets 14900 of 16173 have ben processed
# Tweets 15000 of 16173 have ben processed
# Tweets 15100 of 16173 have ben processed
# Tweets 15200 of 16173 have ben processed
# Tweets 15300 of 16173 have ben processed
# Tweets 15400 of 16173 have ben processed
# Tweets 15500 of 16173 have ben processed
# Tweets 15600 of 16173 have ben processed
# Tweets 15700 of 16173 have ben processed
# Tweets 15800 of 16173 have ben processed
# Tweets 15900 of 16173 have ben processed
# Tweets 16000 of 16173 have ben processed
# Tweets 16100 of 16173 have ben processed

# %%
string = pd.Series(cleaned_tweets).str.cat(sep=' ')

# %%
stopwords = set(STOPWORDS)
stopwords.update(["https"])

# %%
wordcloud = WordCloud(width=1600, stopwords=stopwords,height=800,max_font_size=200,max_words=50,collocations=False, background_color='black').generate(string)
plt.figure(figsize=(40,30))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
df.head()
# Out:
#                         _id          created_at                   id  \
# 0  63161c9b6f461f12e93f068c 2022-09-05 15:57:28  1566817801838350336
# 1  63161c9b6f461f12e93f068d 2022-09-05 15:57:06  1566817710780010496
# 2  63161c9b6f461f12e93f068e 2022-09-05 15:49:19  1566815751688065027
# 3  63161c9b6f461f12e93f068f 2022-09-05 15:42:34  1566814053057830912
# 4  63161c9b6f461f12e93f0690 2022-09-05 15:41:08  1566813689038401541
#
#                 id_str  \
# 0  1566817801838350336
# 1  1566817710780010496
# 2  1566815751688065027
# 3  1566814053057830912
# 4  1566813689038401541
#
#                                                                                                                                                 text  \
# 0  RT @JoshiPralhad: Become part of 2 days National Mines Minister's Conference on 9th &amp; 10th hosted by @MinesMinIndia.\n\nMinisters, Principle…
# 1      RT @PIB_Coal: https://t.co/VdAj2lLILx\nOverall coal production  goes up to 58.33 million ton in August ;  25 mines' production goes beyond 1…
# 2       RT @Rajeev_GoI: Expert Committee on DLI Scheme met at @GoI_MeitY tdy to brainstorm strategy n roadmap for creating 100 new Indian startups/…
# 3                                      Let’s check your knowledge about steel.\n#DidYouKnow \n#ispatigyan #AatmaNirbharSteel https://t.co/6HUsTqNJLf
# 4       RT @dpradhanbjp: #PMShriSchools~14,500 exemplar schools across the country to showcase the implementation of NEP 2020 and facilitate creati…
#
#    truncated  \
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
#                                                                                                                                                                                                   entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'JoshiPralhad', 'name': 'Pralhad Joshi', 'id': 2845994058, 'id_str': '2845994058', 'indices': [3, 16]}, {'screen_name': 'MinesMinI...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'PIB_Coal', 'name': 'PIB_Coal', 'id': 1438442513874907138, 'id_str': '1438442513874907138', 'indices': [3, 12]}], 'urls': [{'url':...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Rajeev_GoI', 'name': 'Rajeev Chandrasekhar 🇮🇳', 'id': 28082599, 'id_str': '28082599', 'indices': [3, 14]}, {'screen_name': 'GoI_M...
# 3  {'hashtags': [{'text': 'DidYouKnow', 'indices': [40, 51]}, {'text': 'ispatigyan', 'indices': [53, 64]}, {'text': 'AatmaNirbharSteel', 'indices': [65, 83]}], 'symbols': [], 'user_mentions': [], 'ur...
# 4  {'hashtags': [{'text': 'PMShriSchools', 'indices': [17, 31]}], 'symbols': [], 'user_mentions': [{'screen_name': 'dpradhanbjp', 'name': 'Dharmendra Pradhan', 'id': 1897514666, 'id_str': '1897514666...
#
#                                                                                  source  \
# 0  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 1  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 4    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#   in_reply_to_status_id in_reply_to_status_id_str  ... retweet_count  \
# 0                  None                      None  ...           108
# 1                  None                      None  ...            11
# 2                  None                      None  ...             4
# 3                  None                      None  ...             0
# 4                  None                      None  ...            25
#
#   favorite_count favorited retweeted lang possibly_sensitive  \
# 0              0     False     False   en                NaN
# 1              0     False     False   en              False
# 2              0     False     False   en                NaN
# 3              3     False     False   en              False
# 4              0     False     False   en                NaN
#
#                                                                                                                                                                                          extended_entities  \
# 0                                                                                                                                                                                                      NaN
# 1                                                                                                                                                                                                      NaN
# 2                                                                                                                                                                                                      NaN
# 3  {'media': [{'id': 1566814041435406337, 'id_str': '1566814041435406337', 'indices': [84, 107], 'media_url': 'http://pbs.twimg.com/media/Fb5xEcDaAAEkzCh.jpg', 'media_url_https': 'https://pbs.twimg.c...
# 4                                                                                                                                                                                                      NaN
#
#   quoted_status_id quoted_status_id_str  quoted_status
# 0              NaN                  NaN            NaN
# 1              NaN                  NaN            NaN
# 2              NaN                  NaN            NaN
# 3              NaN                  NaN            NaN
# 4              NaN                  NaN            NaN
#
# [5 rows x 30 columns]

# %%
df['created_at']=pd.to_datetime(df['created_at'])

# %%
print(type(df['created_at'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
